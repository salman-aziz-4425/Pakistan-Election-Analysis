# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df=pd.read_csv('/content/newData.csv')
df = pd.DataFrame(df)
turnCoats=df.drop_duplicates(subset=['Candidate', 'Party'])
turnCoats=df[df.duplicated(subset='Candidate')==True]
turnCoats=turnCoats.drop_duplicates(subset=['Candidate', 'Party'])
nonturnCoats=df[df.duplicated(subset='Candidate')==False]
nonturnCoats=nonturnCoats.drop_duplicates(subset=['Candidate', 'Party'])
print(df)

# %%
years=[2002,2008,2013,2018]
totalTurnCOatsWinners=[]
for x in years:
     (rows,col)=turnCoats[(turnCoats.Position=='Winner')&(turnCoats.Year==x)].shape
     totalTurnCOatsWinners.append(rows)

NonturnCoatsWinners=[]
for x in years:
     (rows,col)=nonturnCoats[(nonturnCoats.Position=='Winner')&(nonturnCoats.Year==x)].shape
     NonturnCoatsWinners.append(rows)

# %%
X_axis = np.arange(len(years))
plt.bar(X_axis - 0.2, totalTurnCOatsWinners, 0.4, label = 'TurnCoats')
plt.bar(X_axis + 0.2,NonturnCoatsWinners, 0.4, label = 'Non TurnCoats')
X = ['2002','2008','2013','2018']
plt.xticks(X_axis, X)
plt.xlabel("Election Years")
plt.ylabel("Total Winners")
plt.title("Winners of elections 2002-2018")
plt.legend()
plt.show()

# %%
df=pd.read_csv('/content/newData.csv')
df = pd.DataFrame(df)
mylist = list(dict.fromkeys(df['Party']))
print(mylist)
# Out:
# ['ANP', 'PPP', 'IND', 'AQP', 'JUI', 'PTI', 'PPP-SB', 'NPP-WG', 'HPG', 'PKMAP', 'TIP', 'PAP', 'PML-N', 'PML-J', 'JUI-S', 'PML-J Chattha', 'JUP-Noorani', 'PPP-ZAB', 'PML-Q Shuja', 'NPP', 'JMP', 'PSL', 'MJAH', 'MIP', 'PDP', 'KT', 'TI', 'AI', 'WP', 'SI', 'AIMP', 'SNP', 'JWP', 'PMI', 'UNA', 'MQM-H', 'MKP-KBG', 'AT', 'PKQP', 'PML-F', 'MWM', 'PakNP', 'ST', 'BNP', 'BNM', 'KJPP', 'JQM', 'JIP', 'PPPP', 'PML', 'MQMP', 'MMA', 'MQM', nan, 'NMP', 'PAT', 'PMKP', 'LPP', 'PFP', 'SURA', 'PMA', 'PIT', 'PML-Z', 'LPP-K', 'BNDP', 'QJP', 'IP', 'PWrP', 'IMH', 'BNC', 'AHTP', 'PPP-S', 'PMP', 'PBP', 'PCM', 'PTI-Inqalab', 'PAmP', 'PQP', 'PGP', 'JAHP-EZ', 'MJUP (FK)', 'PNP', 'APP', 'Pasban', 'SUP', 'PQL', 'HDP', 'BNP-A', 'NP', 'JI', 'TTP', 'PPM', 'MDM', 'APML', 'QWP', 'JPP', 'TIUP', 'AJIP', 'PJP', 'AWP', 'JUI-Nazryati', 'TM', 'TSH', 'PML-S', 'AMLP', 'HAIP', 'PML-H', 'PSP', 'PML-M', 'MQP', 'MWMP', 'PWP', 'CPM', 'SIC', 'CPP', 'PAI', 'PST', 'MJMP', 'IRP', 'PFP-Falah', 'SPkP', 'PIHP', 'JAKUFR', 'ITP', 'IPM', 'AJPP',
# ...

# %%
turnCoatsWinners=[]
nonturnCoatsWinners=[]
Involved_parties=list(mylist)
count=0
for x in mylist:
    (partyturnCoat,col1)=turnCoats[(turnCoats.Party==x)&(turnCoats.Position=='Winner')].shape
    (partyNONCoat,col2)=nonturnCoats[(nonturnCoats.Party==x)&(nonturnCoats.Position=='Winner')].shape
    if partyturnCoat!=0 and partyNONCoat!=0:
       turnCoatsWinners.append(partyturnCoat)
       nonturnCoatsWinners.append(partyNONCoat)
    else:
        Involved_parties.remove(x)

print(len(turnCoatsWinners))
print()

X_axis = np.arange(len(Involved_parties))
plt.subplots(figsize=(18,5))
plt.bar(X_axis -0.2,turnCoatsWinners, 0.4, label = 'TurnCoats')
plt.bar(X_axis + 0.2,nonturnCoatsWinners,0.4, label = 'Non TurnCoats')
X = list(Involved_parties)
plt.xticks(X_axis, X)
plt.xlabel("Winning Parties Of Elections 1997-2018")
plt.ylabel("Total Winners")
plt.title("Elections 1997-2018")
plt.legend()
plt.show()
# Out:
# 18

# %%
df=pd.read_csv('/content/newData.csv')
df = pd.DataFrame(df)
assemblies=list(dict.fromkeys(df['Assembly']))
print(assemblies)
# Out:
# ['National']

# %%
myList=dict.fromkeys(list(df['Party']))
involved=[]
finalAssemblies=[]
for i in [1997,2002,2008,2013,2018]:
    for item in myList:
        (partyturnCoat,col1)=df[(df.Party==item)&(df.Position=='Winner')&(df.Year==i)].shape
        if partyturnCoat!=0:
          involved.append(item)
          finalAssemblies.append(partyturnCoat)
    X_axis = np.arange(len(involved))
    plt.subplots(figsize=(18,5))
    plt.bar(X_axis-0.2,finalAssemblies, 0.4, label = 'Total Winners')
    X = list(involved)
    plt.xticks(X_axis, X)
    plt.xlabel("Winning Parties Of Elections")
    plt.ylabel("Total Winners")
    plt.title("Elections Year:"+str(i))
    plt.legend()
    plt.show()
    finalAssemblies=[]
    involved=[]

# %%
df=pd.read_csv('/content/Previous_Elections_1997-2013 (1).csv',)
df = pd.DataFrame(df)
turnCoats=df.drop_duplicates(subset=['Candidate', 'Party'])
turnCoats=df[df.duplicated(subset='Candidate')==True]
turnCoats=turnCoats.drop_duplicates(subset=['Candidate', 'Party'])
print(turnCoats[turnCoats['Candidate']=='Imran Khan'])
exit
nonturnCoats=df[df.duplicated(subset='Candidate')==False]
df2=pd.read_csv('Election_result_2018.csv')
df2=pd.DataFrame(df2)
df2=df2.set_axis(['constituency', 'Turnout', 'Registered  Votes','Votes', 'Votes Polled', 'Rejected  Votes','Candidate','results__party','results_votes'], axis=1, inplace=False)
LongList=list(df2['results__party'])
shortList=[]
shortForm=''
for i in LongList:
    for j in i:
        if ord(j)>=65 and ord(j)<=90:
            shortForm+=j
    if shortForm=='I':
        shortList.append('IND')
    else:
      if shortForm=='PML-N':
       shortList.append('PMLN')
      elif shortForm=='PPP':
       shortList.append('PPPP')
      else:
         shortList.append(shortForm)
    shortForm=''

df2['Party']=shortList
df2=df2.replace(np.nan,'')
Position=[]
for y in list(df2['constituency']):
    if 'NA-' in y:
        Position.append('Winner')
    else:
        Position.append('')

df2['Position']=Position
df2['Year']=2018
# df=df.columns['Position','Candidate','Party','Votes','% Vote Share','Registered Votes','Valid Votes','Rejected Votes','Turnout','Assembly','Year']
df3=pd.DataFrame(data=df2,columns=['Position','Candidate','Party','Votes','% Vote Share','Registered Votes','Valid Votes','Rejected  Votes','Turnout','constituency','Assembly','Year'])
# mergedFrame=pd.DataFrame()
# df=df.merge(df3)
# Fill the null values in both the datasets
# df3.fillna(0, inplace=True)
# df.fillna(0, inplace=True)
# * Change the data type of columns of both the datasets to match the data types of the columns of `prev_election_df` dataset

print(df3.dtypes)
df3['Position']=df3['Position'].astype('object')
df3['Candidate']=df3['Candidate'].astype('object')
df3['Votes'] = df3['Votes'].astype('object')
df3['Turnout'] = df3['Turnout'].astype('object')
df3['Registered Votes'] = df3['Registered Votes'].astype('float64')
df3['Valid Votes'] = df3['Valid Votes'].astype('float64')
df3['Rejected  Votes'] = df3['Rejected  Votes'].astype('object')
df3['% Vote Share'] = df3['% Vote Share'].astype('float64')
df3['Year'] = df3['Year'].astype('int64')
df3['Assembly']=df3['Assembly'].astype('object')

# # change the data types of the prev_election_df
df['Votes'] = df['Votes'].astype('object')
# df['Turnout'] = df['Turnout'].astype('float64')
df['Registered Votes'] = df['Registered Votes'].astype('float64')
df['Valid Votes'] = df['Valid Votes'].astype('float64')
df['Rejected  Votes'] = df['Rejected  Votes'].astype('object')
# # drop the rejected votes column
# df.drop('Rejected  Votes', axis=1, inplace=True)
# df['Position'] = df['Position'].astype('int64')
# df['% Vote Share'] = df['% Vote Share'].astype('float64')
# df['Year'] = df['Year'].astype('int64')

# df.dtypes

# # df3.dtypes
# print(df.dtypes)
df=pd.concat([df,df3])
print(df)
df.to_csv('/newData.csv')
# Out:
#       Position   Candidate Party   Votes  % Vote Share  Registered Votes  \
# 107          4  Imran Khan   PTI  6001.0          3.00            446445
# 7305         5  Imran Khan   IND  1591.0          2.80            151437
# 14725       13  Imran Khan  MQMP   260.0          0.10            444059
# 25006       30  Imran Khan  APML     7.0          0.01            139892
#
#        Valid Votes  Rejected  Votes Turnout  \
# 107         169914             4848     39%
# 7305         55043             1027     37%
# 14725       175007             5300     41%
# 25006        74927              910     54%
#
#                                             constituency  Assembly  Year
# 107    NA-18 Dera Ismail Khan-cum-Tank-cum-Kulachi (G...  National  1997
# 7305                                     NA-22 Battagram  National  2008
# 14725                                        NA-26 Bannu  National  2013
# 25006                                   PP-197 Multan-IV    Punjab  2013
# ...

# %%
df=pd.read_csv('/content/Previous_Elections_1997-2013 (1).csv',)
df = pd.DataFrame(df)
df=df[df.Assembly!="National"]
turnCoats=df.drop_duplicates(subset=['Candidate', 'Party'])
turnCoats=df[df.duplicated(subset='Candidate')==True]
turnCoats=turnCoats.drop_duplicates(subset=['Candidate', 'Party'])
nonturnCoats=df[df.duplicated(subset='Candidate')==False]
nonturnCoats=nonturnCoats.drop_duplicates(subset=['Candidate', 'Party'])
print(df)
# Out:
#       Position                    Candidate  Party   Votes  % Vote Share  \
# 2067    Winner            Shafiq Ahmed Khan   PPPP  4546.0         29.49
# 2068         2      Naseem -Ur- Rehman Khan  PML-N  3345.0         21.70
# 2069         3          Mujeeb Ahmed Hashmi    PML  2488.0         16.14
# 2070         4  Muhammad Rauf Atta Advocate    MMA  2173.0         14.10
# 2071         5        Syed Abdul Qadir Agha  PKMAP  1331.0          8.64
# ...        ...                          ...    ...     ...           ...
# 29305       40                 Shahzad Ayaz    IND     7.0          0.01
# 29306       41  Sardar Qadir Bux Khan Gabol    IND     7.0          0.01
# 29307       42         Ikhlaq Muhammad Khan    IND     3.0          0.00
# 29308       43                 Hussain Shah    IND     3.0          0.00
# 29309       44          Waheed Murad Shaikh    IND     2.0          0.00
#
#        Registered Votes  Valid Votes  Rejected  Votes Turnout  \
# ...

# %%
assemblies=list(dict.fromkeys(df["Assembly"]))
print(assemblies)
# Out:
# ['Balochistan', 'KPK', 'Punjab', 'Sindh']

# %%
df.fillna(0)

myList=dict.fromkeys(list(df['Party']))
involved=[]
finalAssemblies=[]
# for i in [1997,2002,2008,2013]:
#   for j in assemblies:
#            (partyturnCoat,col1)=df[(df.Party=="PTI")&(df.Position=='Winner')&(df.Assembly==j)&(df.Year==i)].shape
#            finalAssemblies.append(partyturnCoat)
#            print(finalAssemblies)
#   X_axis = np.arange(len(assemblies))
#   plt.subplots(figsize=(18,5))
#   plt.bar(X_axis-0.2,finalAssemblies, 0.4, label = 'Total Winners')
#   X = list(assemblies)
#   plt.xticks(X_axis, X)
#   plt.xlabel("Winning Parties Of Elections")
#   plt.ylabel("Total Winners")
#   plt.title("Elections Won by PTI across all:")
#   plt.legend()
#   plt.show()
#   finalAssemblies=[]

px.scatter(df, x="Votes", y="Position", animation_frame="Assembly", animation_group="Party",
           size="Valid Votes", color="Party", hover_name="Party",
           log_x=True, size_max=55, range_x=[1,100000], range_y=[-20,102])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df=pd.read_csv('/content/NA-Results2018 Ver 2.csv',)
df = pd.DataFrame(df)
df
# Out:
#       Unnamed: 0 district                Seat Constituency_Title  \
# 0              0  Chitral             Chitral               NA-1
# 1              1  Chitral             Chitral               NA-1
# 2              2  Chitral             Chitral               NA-1
# 3              3  Chitral             Chitral               NA-1
# 4              4  Chitral             Chitral               NA-1
# ...          ...      ...                 ...                ...
# 3423        3423  Lasbela  Lasbela-cum-Gwadar             NA-272
# 3424        3424  Lasbela  Lasbela-cum-Gwadar             NA-272
# 3425        3425  Lasbela  Lasbela-cum-Gwadar             NA-272
# 3426        3426  Lasbela  Lasbela-cum-Gwadar             NA-272
# 3427        3427  Lasbela  Lasbela-cum-Gwadar             NA-272
#
#                         Candidate_Name                              Part  \
# 0         Moulana Abdul Akbar Chitrali  Muttahida Majlis-e-Amal Pakistan
# ...

# %%
assemblies=list(dict.fromkeys(df["district"]))
print(assemblies)
# Out:
# ['Chitral', 'Swat', 'Upper', 'Lower', 'Malakand', 'Buner', 'Shangla', 'Kohistan', 'Battagram', 'Mansehra', 'Abbottabad', 'Haripur', 'Swabi', 'Mardan', 'Charsadda', 'Nowshera', 'Peshawar', 'Kohat', 'Hangu', 'Karak', 'Bannu', 'Lakki', 'Tank', 'Dera', 'Tribal', 'Islamabad', 'Attock', 'Rawalpindi', 'Chakwal', 'Jhelum', 'Gujrat', 'Sialkot', 'Narowal', 'Gujranwala', 'Mandi', 'Hafizabad', 'Sargodha', 'Khushab', 'Mianwali', 'Bhakkar', 'Chiniot', 'Faisalabad', 'Toba', 'Jhang', 'Nankana', 'Sheikhupura', 'Lahore', 'Kasur', 'Okara', 'Pakpattan', 'Sahiwal', 'Khanewal', 'Multan', 'Lodhran', 'Vehari', 'Bahawalnagar', 'Bahawalpur', 'RahimYar', 'Muzaffargarh', 'Layyah', 'Rajanpur', 'Jacobabad', 'Kashmore', 'Shikarpur', 'Larkana', 'Kamber', 'Ghotki', 'Sukkur', 'Khairpur', 'Naushahro', 'Shaheed', 'Sanghar', 'Mirpurkhas', 'Umerkot', 'Tharparkar', 'Matiari', 'Tando', 'Hyderabad', 'Badin', 'Sujawal', 'Thatta', 'Jamshoro', 'Dadu', 'Malir', 'Korangi', 'Karachi', 'Killa', 'Loralai', 'Nasirabad', 'Jafarabad',
# ...

# %%
Total_Votes=[]
parties=[]
df=df[(df.Total_Rejected_Votes>0)&(df.Part=='Pakistan Tehreek-e-Insaf')]
# Out:
#       Unnamed: 0   district                     Seat Constituency_Title  \
# 11            11       Swat                   Swat-I               NA-2
# 21            21       Swat                  Swat-II               NA-3
# 29            29       Swat                 Swat-Ill               NA-4
# 40            40      Upper                    Upper               NA-5
# 50            50      Lower                    Lower               NA-6
# ...          ...        ...                      ...                ...
# 3055        3055    Karachi                  Karachi             NA-252
# 3090        3090    Karachi                  Karachi             NA-254
# 3122        3122    Karachi                  Karachi             NA-256
# 3225        3225  Jafarabad  Jafarabad-cum-Sohbatpur             NA-261
# 3283        3283     Quetta                Quetta-II             NA-265
#
#                 Candidate_Name                      Part  Votes  \
# ...

# %%
assemblies=list(dict.fromkeys(df["district"]))
print(assemblies)
print(len(assemblies))
# for i in assemblies:
#   shap1,col=df[(df.district==i)].groupby("district")['Candidate_Name','Votes'].max().shape
#   row=df[(df.district==i)].groupby("district")['Candidate_Name','Votes'].max()
#   print(shap1)
#   print(row['Votes'])
#   break
# Out:
# ['Chitral', 'Swat', 'Upper', 'Lower', 'Malakand', 'Buner', 'Shangla', 'Kohistan', 'Battagram', 'Mansehra', 'Abbottabad', 'Haripur', 'Swabi', 'Mardan', 'Charsadda', 'Nowshera', 'Peshawar', 'Kohat', 'Hangu', 'Karak', 'Bannu', 'Lakki', 'Tank', 'Dera', 'Tribal', 'Islamabad', 'Attock', 'Rawalpindi', 'Chakwal', 'Jhelum', 'Gujrat', 'Sialkot', 'Narowal', 'Gujranwala', 'Mandi', 'Hafizabad', 'Sargodha', 'Khushab', 'Mianwali', 'Bhakkar', 'Chiniot', 'Faisalabad', 'Toba', 'Jhang', 'Nankana', 'Sheikhupura', 'Lahore', 'Kasur', 'Okara', 'Pakpattan', 'Sahiwal', 'Khanewal', 'Multan', 'Lodhran', 'Vehari', 'Bahawalnagar', 'Bahawalpur', 'RahimYar', 'Muzaffargarh', 'Layyah', 'Rajanpur', 'Jacobabad', 'Kashmore', 'Shikarpur', 'Larkana', 'Kamber', 'Ghotki', 'Sukkur', 'Khairpur', 'Naushahro', 'Shaheed', 'Sanghar', 'Mirpurkhas', 'Umerkot', 'Tharparkar', 'Matiari', 'Tando', 'Hyderabad', 'Badin', 'Sujawal', 'Thatta', 'Jamshoro', 'Dadu', 'Malir', 'Korangi', 'Karachi', 'Killa', 'Loralai', 'Nasirabad', 'Jafarabad',
# ...

# %%
X_axis = np.arange(len(assemblies))
  plt.subplots(figsize=(18,5))
  plt.bar(X_axis-0.2,finalAssemblies, 0.4, label = 'Total Winners')
  X = list(assemblies)
  plt.xticks(X_axis, X)
  plt.xlabel("Winning Parties Of Elections")
  plt.ylabel("Total Winners")
  plt.title("Elections Won by PTI across all:")
  plt.legend()
  plt.show()
  finalAssemblies=[]

# %%
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 286]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
def plotCorrelationMatrix(df, graphWidth):
    filename = "Election 2018"
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
plotCorrelationMatrix(df, 8)
# Out:
# <ipython-input-71-be5e42deecb2>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df = df.dropna('columns') # drop columns with NaN

# %%
px.scatter(df, x="Votes", y="Part", animation_frame="district", animation_group="district",
           size="Votes", color="Part", hover_name="Part",
           log_x=True, size_max=55, range_x=[100,10000000], range_y=[25,90])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
nRowsRead = 1000
df=pd.read_csv('/Kaggle v5 - Election Data.csv', delimiter=',', nrows = nRowsRead)
df.dataframeName = 'Kaggle v5 - Election Data.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
df
# Out:
# There are 1000 rows and 13 columns
#      Unnamed: 0    District           Seat Constituency_title  \
# 0             0    PESHAWAR     PESHAWAR-I               NA-1
# 1             1    PESHAWAR     PESHAWAR-I               NA-1
# 2             2    PESHAWAR     PESHAWAR-I               NA-1
# 3             3    PESHAWAR    PESHAWAR-II               NA-2
# 4             4    PESHAWAR    PESHAWAR-II               NA-2
# ..          ...         ...            ...                ...
# 995         995  RAWALPINDI  RAWALPINDI-IV              NA-39
# 996         996  RAWALPINDI  RAWALPINDI-IV              NA-39
# 997         997  RAWALPINDI  RAWALPINDI-IV              NA-39
# 998         998  RAWALPINDI  RAWALPINDI-IV              NA-39
# 999         999  RAWALPINDI  RAWALPINDI-IV              NA-39
#
#                      Candidate_Name   Party  Votes  Total_Valid_Votes  \
# 0           Muhammad Yousaf Khattak  PML(Q)  44507            79847.0
# ...
